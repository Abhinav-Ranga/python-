# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav-Ranga/python-/blob/main/pythonOOPS_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Write OOP classes to handle the following scenarios:
#
# A user can create and view 2D coordinates
#
# A user can find out the distance between 2 coordinates
#
# A user can find find the distance of a coordinate from origin
#
# A user can check if a point lies on a given line
#
# A user can find the distance between a given 2D point and a given line

# %%
class point:

  def __init__(self,x,y):
    self.x_cord = x
    self.y_cord = y

  def __str__(self):
    return '<{},{}>'.format(self.x_cord,self.y_cord)



  def euclidean_distance(self,other):
    return ((self.x_cord - other.x_cord) **2 +  (self.y_cord - other.y_cord) **2) **0.5


  def distance_from_original(self):
    return self.euclidean_distance(p1)




class line:
  def __init__(self,a,b,c):
    self.a = a
    self.b = b
    self.c = c

  def __str__(self):
    return '{}x+{}b+{}c = 0'.format(self.a,self.b,self.c)



  def point_on_line(line,point):
    if line.a*point.x_cord + line.b*point.y_cord + line.c == 0:
         return 'lies on the line'
    else:
      return "'doesn't lie on the line"


  def shortest_distance(line,point):
    return abs(line.a*point.x_cord+line.b*point.y_cord+line.c)/(line.a**2+line.b**2)**0.5

# %%
p1 = point(0,0)
p2 = point(1,1)

p1.euclidean_distance(p2)
p1.distance_from_original()
# Out:
# 0.0

# %%
l1 = line(1,1,-2)
p1 = point(1,10)
l1.point_on_line(p1)
l1.shortest_distance(p1)
# Out:
# 6.363961030678928

# %% [markdown]
# # Homework
# you have to make a method which will tell do two line segments intersect or not

# %%
class person:
  def __init__(self,name_input,country_input):
    self.name = name_input;
    self.country = country_input;

  def greet(self):
    if self.country == 'india':
      print('jai jai shree harivansh')
    else :
      print('hello')

# %%
# how to access attributes
p = person('harivansh','australia')
p.country
# Out:
# 'australia'

# %%
# how to access methods
p.greet()
# Out:
# hello

# %%
# what if we access a attribute that is not present

p.gender # this attribute is not present in our class so error
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1562/3636404850.py in <cell line: 0>()
#       1 # what if we access a attribute that is not present
#       2
# ----> 3 p.gender # this attribute is not present in our class so error
#
# AttributeError: 'person' object has no attribute 'gender'

# %% [markdown]
# # Attributes creation outside of the class

# %%
p.gender = 'male' # we can create attributes oustide of the class
p.gender

# %% [markdown]
# # Reference Variables
#
# Reference variables hold the objects
#
# We can create objects without reference variable as well
#
# An object can have multiple reference variables
#
# Assigning a new reference variable to an existing object does not create a new object

# %%
# object without reference

class person:
  def __init__(self):
    self.name = 'abhinav'
    self.age = '324'

# %%
# we can create object without variables but  we use variable coz object will be lost in memory
# person()
p = person()
print(p)

# %%
# multiple reference
q = p


print(id(p))
print(id(q))
# Out:
# 135452719253600
# 135452719253600

# %%
# change attributes with the help of 2nd object
print(p.name)
print(q.name)
q.name = 'radha'
print(p.name)
print(q.name)
# Out:
# radha
# radha
# radha
# radha

# %% [markdown]
# # Pass by reference
#
#
# we can actual pass object of a class to the function
#
#
#
#  when u pass object as input in function u don't pass the object u pass the adddress of the object
#
#
#
#   a function can even return objects

# %%
# in python ur object and  class name can't be same but in java u can do this thing
class Person:
  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class function
def greet(person):
  print('hi my name is ',person.name,'and i am',person.gender)
  p1 = Person('ankit','male')
  return p1



p = person('nitish','male')
x = greet(p)
print(x.name)
print(x.gender)
# Out:
# hi my name is  nitish and i am male
# ankit
# male

# %%
class Person:
  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class function
def greet(person):
  print('hi my name is ',person.name,'and i am',person.gender)
  person.name = 'ankit'
  print(person.name)

p = person('nitish','male')
greet(p)
print(p.name)
# Out:
# hi my name is  nitish and i am male
# ankit
# ankit

# %% [markdown]
# # mutability of the object
#
# by default all objects are mutable in python (user defined classes are mutable)
#
# but we can make them immutable

# %% [markdown]
# in python ur object and  class name can't be same but in java u can do this thing

# %%
class Person:
  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# outside the class function
def greet(person):
  print('hi my name is ',person.name,'and i am',person.gender)
  person.name = 'ankit'
  print(person.name)

p = person('nitish','male')
print(id(p))
greet(p)
print(p.name)
print(id(p))
# Out:
# 135452709587232
# hi my name is  nitish and i am male
# ankit
# ankit
# 135452709587232

# %% [markdown]
# #Instance variable
# is a variable thats value depends upon object

# %% [markdown]
# # Enacapsulation

# %%
# creating an ATM Machine

class Atm :
  def __init__(self):
    self. __pin = ''
    self.__balance = 0
    # self.menu()



  def get_balance(self):
    return self.balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.balance = new_value
    else:
      print('nikal beta')


  def menu(self):
      user_input = input("""   how can i help u
      1: press 1 to create pin
      2: press 2 to change pin
      3: press 3 to check balance
      4: press 4 wihtdraw amount
      5: Anything else to exit
      """)

      if user_input == '1':
        self.create_pin()
      elif user_input == '2':
        self.change_pin()
      elif user_input == '3':
        self.check_balance()
      else:
        self.withdraw()


  def create_pin(self):
    user_pin = input("enter the pin: ")
    self.pin = user_pin

    user_balance = int(input("enter the balance: "))
    self.balance = user_balance
    print("pin created successfully: ")
    # self.menu()



  def change_pin(self):
    old_pin = input("Enter old pin: ")

    if old_pin == self.pin:
      new_pin = input('enter then new pin: ')
      self.pin = new_pin
      print('pin changed successfully')
      self.menu()
    else:
      print('mere bus ki nahi hai rey bhai : ')
      self.menu()



  def check_balance(self):
    user_input = input("enter the pin: ")
    if user_input == self.pin:
      print("ur balance is: ",self.balance)
    else :
      print("banau hoshiyaar shyaane: ")
      self.menu()

  def withdraw(self):
    user_input = input('enter the pin: ')
    if user_input == self.pin:
      amount = int(input('enter the amount to withdraw: '))
      if amount<=self.balance:
        self.balance = self.balance - amount
        print('withdraw successfully')
        print('ur balance is: ', self.balance)
        self.menu()
      else :
        print('aukat ke bahar mat bola kar bete: ')
        self.menu()

    else:
      print('saley chor: ')
      self.menu()

# %%
obj = Atm()

# %%
obj.create_pin()
obj.balance = 'hehe'
# Out:
# enter the pin: 1234
# enter the balance: 1000
# pin created successfully:

# %%
obj.set_balance('dfgs')
# Out:
# nikal beta

# %% [markdown]
# # In python there is nothing truly private
#
#
# #Reason
#
# python is a programmaing language made for adults u are mature enough not to touch other's thing and by using double underscore u can hide it now user will undersand we don't have to touch it
#
#
#
#
# #Conclusion
#
# make it a habit always make ur data inside class private
#
#
#
# but ur private data is still accessible for the one who is inside the class

# %% [markdown]
# so the meaning of encapsulation is we can change our attributes value by outside of the class so this is very dangerous anyone can change the logic of u code
#
# so to prevent our code from this thing we use
# 'private' and the syntax of private is
#
# __ (double underscore)
#
# so by making private we can hide our variables that we don't want
#
# but there is a issue here if the user gets to know about that u have used private  so by writing syntax of private it can change the code
#
# but here is a twist even if user change something still u will not get any error coz
#
# when we make something private inside memory it changes its name to
#
# _ClassName__variableName
#
# so by changing something in attribute ur code will be same coz it didn't affect ur actual code
#
# but here is an another twist
#
# user can still  change ur values by using
#
# _ClassName__variableName
#
#
# conclusion = nothing is private in python
#
#
# but still there is one more thing if user is a good guy and he really wants to access the private things as well as change them for work but u have doubt he would change the attributes value unnecessarily so to prevent form that thing u have two things
#
#
# create two methods
# 1:getter = to get the value outside of the class
#
# 2:Setter = to change the private value outside of the class
#
#
# but the benefits of this thing is u are giving the user to use and change the value if he seriously needs but u can give conditions if he is doing genuineily changes then he can otherwise he can't

# %% [markdown]
# #Collection of objects

# %%
# list of objects
class person:
  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# %%
p1 = person('nitish','male')
p2 = person('ankit','male')
p3 = person('ankita','female')

# %% [markdown]
# when we print here we  get only memory address until we don't use str method but if we print single attribute or method we can print them but to print all the attributes we need str method

# %%
L = [p1,p2,p3]
print(L)
p1.gender
# Out:
# [<__main__.person object at 0x7ef894ac8b30>, <__main__.person object at 0x7ef894ac8da0>, <__main__.person object at 0x7ef894ac8920>]
# 'male'

# %% [markdown]
# we can create objects and store it into list and use them same as list

# %%
for i in L:
  print(i.name,i.gender)
# Out:
# nitish male
# ankit male
# ankita female

# %%
# homework
# make objects and store it into set [honest they should not be stored
# but they will be stored and u have to find the reason also ]

# %%
# dictionary of objects

class Person:
  def __init__(self,name,gender):
    self.name = name
    self.gender = gender

# %%
p1 = person('nitish','male')
p2 = person('ankit','male')
p3 = person('ankita','female')

# %%
d = {'p1':p1,'p2':p2,'p3':p3}
print(d)
# Out:
# {'p1': <__main__.person object at 0x7ef87fb22b40>, 'p2': <__main__.person object at 0x7ef87f5000e0>, 'p3': <__main__.person object at 0x7ef87f501310>}

# %%
for i in d:
  print(d[i].name,d[i].gender)
# Out:
# nitish male
# ankit male
# ankita female

# %% [markdown]
# #Static variable vs Instance variable
#
#
#
# instance = it is of object variable every object has a different value
#
# it is declared inside constructor
#
# we fetch it by  objName.Variable name
#
# static  = it a of class varaible
#
# thats value is same for all objects
#
#  we fetch it by class name.VaraibleName
#
#  it is declared inside the class but outside of methods
#
#
#
#
#  and we can even make static method private anb use get set but  here it is not using self so we can avoid self in this method
#
#
#  but we access it by using class name and method name
#
#
#
#  # u can access these methods without even creating the objects by just using class name

# %%
# creating an ATM Machine

class Atm :
  __counter = 1
  def __init__(self):
    self.__pin = ''
    self.__balance = 0


    # self.cid = 0  #: for instance
    # self.cid += 1 #: for instance


    self.cid = Atm.__counter
    Atm.counter += 1

# this is utility functions
  @staticmethod
  def get_counter():
    return Atm.__counter


  def get_balance(self):
    return self.balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.balance = new_value
    else:
      print('nikal beta')


  def menu(self):
      user_input = input("""   how can i help u
      1: press 1 to create pin
      2: press 2 to change pin
      3: press 3 to check balance
      4: press 4 wihtdraw amount
      5: Anything else to exit
      """)

      if user_input == '1':
        self.create_pin()
      elif user_input == '2':
        self.change_pin()
      elif user_input == '3':
        self.check_balance()
      else:
        self.withdraw()


  def create_pin(self):
    user_pin = input("enter the pin: ")
    self.pin = user_pin

    user_balance = int(input("enter the balance: "))
    self.balance = user_balance
    print("pin created successfully: ")
    # self.menu()



  def change_pin(self):
    old_pin = input("Enter old pin: ")

    if old_pin == self.pin:
      new_pin = input('enter then new pin: ')
      self.pin = new_pin
      print('pin changed successfully')
      self.menu()
    else:
      print('mere bus ki nahi hai rey bhai : ')
      self.menu()



  def check_balance(self):
    user_input = input("enter the pin: ")
    if user_input == self.pin:
      print("ur balance is: ",self.balance)
    else :
      print("banau hoshiyaar shyaane: ")
      self.menu()

  def withdraw(self):
    user_input = input('enter the pin: ')
    if user_input == self.pin:
      amount = int(input('enter the amount to withdraw: '))
      if amount<=self.balance:
        self.balance = self.balance - amount
        print('withdraw successfully')
        print('ur balance is: ', self.balance)
        self.menu()
      else :
        print('aukat ke bahar mat bola kar bete: ')
        self.menu()

    else:
      print('saley chor: ')
      self.menu()

# %%
c1 = Atm()

# %%
c2 = Atm()

# %%
c3 =Atm()

# %%
c1.cid # instance
# Out:
# 1

# %%
c2.cid # instance
# Out:
# 1

# %%
c3.cid # instance
# Out:
# 1

# %%
c1.cid # static
# Out:
# 1

# %%
c2.cid # static
# Out:
# 2

# %%
c3.cid # static
# Out:
# 3

# %%
Atm.get_counter()
# Out:
# 1
