# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinav-Ranga/python-/blob/main/python9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Class relationship
#
# : Aggregation
#
# : inheritance

# %% [markdown]
# # Aggregation has a relation ship

# %% [markdown]
# so we are making a class name customer
#
# so name and gender are very easy to access but address is very complex
#
# so we made a different class for that address and after that made a
#
# object of it and stored that object in constructor of customer

# %%
# example

class Customer:
  def __init__(self,name,gender,address):
    self.name = name
    self.gender = gender
    self.address = address

  def print_address(self):
    return( self.address.pincode,self.address.get_city(),self.address.state  )


  def edit_profile(self,new_name,new_city,new_state,new_pincode):
    self.name = new_name
    self.address.edit_Address(new_pincode,new_city,new_state)

class  Address:
    def __init__(self,pincode,city,state):
      self.pincode = pincode
      self.__city = city
      self.state = state

    def get_city(self):
      return self.__city



    def edit_Address(self,new_pincode,new_city,new_state):
      self.pincode = new_pincode
      self.__city = new_city
      self.state = new_state

# %%
add1  = Address(122102,'gurugram','haryana')
cust1 = Customer('abhinav','gender',add1)

print( cust1.print_address())

cust1.edit_profile('ankit','delhi','india',122198)

cust1.print_address()
# Out:
# (122102, 'gurugram', 'haryana')
# (122198, 'delhi', 'india')

# %% [markdown]
# summary
#
# there are relationships between class
# there are two types of relationships
#
# (1) aggregation = when there is has a relationship between two class means
# one class owns another class
#
#
#
# # In aggregation the own class can't access the owned class private variables

# %% [markdown]
# # Inheritance
#
# what is inheritance
#
# example
#
# what gets inherited?

# %%
# Inheritance and it's benefits

# %%
# example


# Parent class
class user :
  def __init__(self):
    self.name = 'abhinav'

  def login(self):
    print("login")


# child class
class Student(user):
  # def __init__(self): # if child class has constructor we don't use parent class constructor
  #   self.rollno = 100

  def enroll(self):
    print("enroll into the class: ")

# %%
u = user()
s = Student()

# %%
print(s.name)
s.enroll()
s.login()
# Out:
# abhinav
# enroll into the class:
# login

# %%
# class diagram

# %% [markdown]
# # What gets inherited
#
# constructor
#
# non private attributes
#
# non private methods

# %% [markdown]
# # Concept no 1
# if child has no  constructor than parent constructor will be called
#
#
#
# # Concept no 2
# if child has constructor then parent constructor will not be called coz they will not be initialized
# then child will not be able to accesss those variables of parent class
#
#
# #Concept 3
# child class object can access anything except private members ,data and methods

# %%
# constructor example
class phone:
  def __init__(self,price,brand,camera):
    self.price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print('buy phone')




class SmartPhone(phone):
  pass

# %%
s = SmartPhone(20000,'Apple',13)

s.brand
s.buy()
# Out:
# buy phone

# %%
# constructor example 2
class phone:
  def __init__(self,price,brand,camera):
    self.price = price
    self.brand = brand
    self.camera = camera


class SmartPhone(phone):
  def __init__(self,os,ram):
    self.os = os
    self.ram = ram
    print("inside child constructor")

# %%
s1 = SmartPhone('android',8)
# Out:
# inside child constructor

# %%
# child class can't access the private memebers of the class

class phone:
  def __init__(self,price,brand,camera):
    print('inside phone constructor')
    self.__price = price
    self.brand = brand
    self.camera = camera

# show is working as getter
  def __show(self):
    print(self.__price)


class SmartPhone(phone):
  def check(self):
    print(self.__price)

# %%
s2 = SmartPhone(20000,'samsung',13)
print(s2.brand)
s2.show()
# Out:
# inside phone constructor
# samsung
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2954/2298054834.py in <cell line: 0>()
#       1 s2 = SmartPhone(20000,'samsung',13)
#       2 print(s2.brand)
# ----> 3 s2.show()
#
# AttributeError: 'SmartPhone' object has no attribute 'show'

# %%
# Example questions 1


class Parent:

    def __init__(self, num):
        self.__num = num

    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print("This is in child class")

son = Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# This is in child class

# %%
# example 2
class Parent:

    def __init__(self, num):
        self.__num = num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self, val, num):
        self.__val = val

    def get_val(self):
        return self.__val

son = Child(100, 10)
print("Parent: Num:", son.get_num())
print("Child: Val:", son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2954/529140373.py in <cell line: 0>()
#      16
#      17 son = Child(100, 10)
# ---> 18 print("Parent: Num:", son.get_num())
#      19 print("Child: Val:", son.get_val())
#
# /tmp/ipykernel_2954/529140373.py in get_num(self)
#       5
#       6     def get_num(self):
# ----> 7         return self.__num
#       8
#       9 class Child(Parent):
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
# example no 3
class A:
    def __init__(self):
        self.var1 = 100

    def display1(self, var1):
        print("class A :", self.var1)

class B(A):

    def display2(self, var1):
        print("class B :", self.var1)

obj = B()
obj.display1(200)
# Out:
# class A : 100

# %% [markdown]
# # Method overriding
#
# if there is inheritance and both have same methods then child method will be executed

# %%
class Phone:
  def __init__(self,price,brand,camera):
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("Buying a Phone")


class SmartPhone(phone):
  def buy(self):
    print("Buying a smartPhone")

# %%
s = SmartPhone(20000,'samsung',13)
p = Phone(20000,'samsung',13)
s.buy()
p.buy()
# Out:
# Buying a smartPhone
# Buying a Phone

# %% [markdown]
# # Super Keyword
#
# from child constructor u will call super keyword and by super keyword u can call parent constructor and by this u can initialize parent constructor
#
# u can't use super keyword outside of the class
#
#
# super keyword is always used inside child class
#
#
# u can access only methods not attributes using super

# %%
class Phone:
  def __init__(self,price,brand,camera):
    print("Inside phone constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("Buying a Phone")


class SmartPhone(Phone):
  def buy(self):
    print("Buying a smartPhone")
    #syntax to call parent ka buy method
    super().buy()

# %%
s = SmartPhone(2000,"apple",13)
s.buy()
# Out:
# Inside phone constructor
# Buying a smartPhone
# Buying a Phone

# %%
class Phone:
  def __init__(self,price,brand,camera):
    print("Inside phone constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

  def buy(self):
    print("Buying a Phone")


class SmartPhone(Phone):
   def __init__(self,price,brand,camera,os,ram):
    print("inside smartphone constructor")
    super().__init__(price,brand,camera)
    self.os = os
    self.ram = ram
    print("inside smartphone constructor")

# %%
s = SmartPhone(2000,"Samsung",12,"Android",2)
print(s.os)
print(s.ram)
print(s.brand)
# Out:
# inside smartphone constructor
# Inside phone constructor
# inside smartphone constructor
# Android
# 2
# Samsung

# %% [markdown]
# # Inheritance in summary
#
# A class can inherit from another class.
#
# Inheritance improves code reuse
#
# Constructor, attributes, methods get inherited to the child class
#
# The parent has no access to the child class
#
# Private properties of parent are not accessible directly in child class
#
# Child class can override the attributes or methods. This is called method overriding
#
# super() is an inbuilt function which is used to invoke the parent class methods and constructor

# %% [markdown]
# # Types of inheritance
#
#
# single inheritance
#
# multilevel inheritance
#
# hiearchical inheritance
#
# multiple inheritance =  it is not in java
#
# hybrid inheritance

# %%
# multilevel inheritance

class Product:
  def review(self):
    print("print customer review")

class Phone(Product):
  def buy(self):
    print("buy phone")

class SmartPhone(Phone):
  def buy(self):
    print("buy smartphone")

# %%
s1 = SmartPhone()
s1.buy()
s1.review()
# Out:
# buy smartphone
# print customer review

# %%
# Hiearchical inheritance

class Phone:
  def __init__(self,price,brand,camera):
    print("inside phone constructor")
    self.__price = price
    self.brand = brand
    self.camera = camera

class SmartPhone(Phone):
  pass

class FeaturePhone(Phone):
  pass

# %%
s = SmartPhone(20000,'samsung',12)
f = FeaturePhone(20090,'samsung',12)

print(f._Phone__price)
# Out:
# inside phone constructor
# inside phone constructor
# 20090

# %%
# the class u write first inside parameter will be called first

# Multiple
class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("Buying a phone")

class Product:
    def review(self):
        print("Customer review")

class SmartPhone(Phone, Product):
    pass

s = SmartPhone(20000, "Apple", 12)
# Out:
# Inside phone constructor

# %%
# Follow link (ctrl + click)
# https://stackoverflow.com/questions/56361048/what-is-the-diamond-problem-in-python-and-why-its-not-appear-in-pytho
class Phone:
    def __init__(self, price, brand, camera):
        print("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print("Buying a phone")

class Product:
    def buy(self):
        print("Product buy method")

class SmartPhone(Product, Phone):
    pass

# (The bottom line is partially cut off but instantiates the class similarly)
# s = SmartPhone(20000, "Apple", 12)

# %%
# Practice question

class A :
  def m1(self):
    return 20

class B(A):
  def m1(self):
    val = super().m1()+30
    return val

class C(B):

  def m1(self):
    val = self.m1() + 20
    return val

# %%
obj = C()
obj.m1()
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# /tmp/ipykernel_484/2588837303.py in <cell line: 0>()
#       1 obj = C()
# ----> 2 obj.m1()
#
# /tmp/ipykernel_484/3301911521.py in m1(self)
#      13
#      14   def m1(self):
# ---> 15     val = self.m1() + 20
#      16     return val
#
# ... last 1 frames repeated, from the frame below ...
#
# /tmp/ipykernel_484/3301911521.py in m1(self)
#      13
#      14   def m1(self):
# ---> 15     val = self.m1() + 20
#      16     return val
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# # Polymorphism
#
# mehtod overriding = if we have same methods name than we would call child class method
#
#
# method overloading = same name of methods but different output based on the input
#
#
# operator overloading = when an operator behaves differently after seeing different inputs
# implementation is in magic methods

# %%
# method overrding doesn't work in python but works in java


# class Shape:  # doesn't work
#   def  area(self,radius):
#     return self.radius ==  radius**2

#   def area(self,radius,value) :
#     return self.radius == value**2



# we do method overlaoding by default method
class Shape:
  def  area(self,a,b=0):
    if b == 0:
      return 3.14 *a*a
    else:
      return a*b

# %%
s = Shape()
print(s.area(2,3))
print(s.area(2))
# Out:
# 6
# 12.56
